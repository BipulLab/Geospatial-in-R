# %% [markdown]
# <a href="https://colab.research.google.com/github/BipulLab/Geospatial-in-R/blob/main/GeospatialP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("bipul kumar")
# Out:
# bipul kumar

# %%
import pandas as pd

# %%
mylist = [34,90,78,8,56,45]

# %%
res = pd.Series(mylist)
print("Series =", res)
# Out:
# Series = 0    34
# 1    90
# 2    78
# 3     8
# 4    56
# 5    45
# dtype: int64

# %%
# !pip install geopandas
# !pip install fiona shapely pyproj rtree
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 8.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 75.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 116.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 77.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 101.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 541.1/541.1 kB 27.8 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd

# %%
gpd.show_versions()
# Out:
# SYSTEM INFO
# -----------
# python     : 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# executable : /usr/bin/python3
# machine    : Linux-6.1.85+-x86_64-with-glibc2.35
#
# GEOS, GDAL, PROJ INFO
# ---------------------
# GEOS       : 3.11.4
# GEOS lib   : None
# GDAL       : 3.9.1
# GDAL data dir: /usr/local/lib/python3.11/dist-packages/pyogrio/gdal_data/
# PROJ       : 9.5.1
# PROJ data dir: /usr/local/lib/python3.11/dist-packages/pyproj/proj_dir/share/proj
#
# PYTHON DEPENDENCIES
# -------------------
# geopandas  : 1.0.1
# numpy      : 2.0.2
# pandas     : 2.2.2
# pyproj     : 3.7.1
# shapely    : 2.0.7
# pyogrio    : 0.10.0
# geoalchemy2: None
# geopy      : None
# matplotlib : 3.10.0
# mapclassify: None
# fiona      : 1.10.1
# psycopg    : None
# psycopg2   : None
# pyarrow    : 19.0.1

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate sample data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# Create plot
plt.figure(figsize=(6,4))
plt.plot(x, y, label="Sine Wave")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Sample Graph")
plt.legend()

# Save as PNG
plt.savefig("graph.png", dpi=300, bbox_inches="tight")  # Save with high resolution
plt.show()

# %%
from google.colab import files
files.download("graph.png")

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# Download the dataset directly from Natural Earth
url = "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip"

# Read the dataset
world = gpd.read_file(url)

# Plot the world map
fig, ax = plt.subplots(figsize=(10, 6))
world.plot(ax=ax, color='lightblue', edgecolor='black')

# Save the map as PNG
plt.savefig("map.png", dpi=300, bbox_inches="tight")
plt.show()

# %%
from google.colab import files
files.download("map.png")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Shapefiles"
# Out:
# ls: cannot access '/content/drive/My Drive/Shapefiles': No such file or directory

# %%
import os
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls "/content/drive/My Drive/BGD_adm"  # Change path based on your folder
# Out:
# BGD_adm0.cpg  BGD_adm0.shp  BGD_adm1.dbf  BGD_adm2.cpg	BGD_adm2.shp  BGD_adm3.dbf  license.txt
# BGD_adm0.csv  BGD_adm0.shx  BGD_adm1.prj  BGD_adm2.csv	BGD_adm2.shx  BGD_adm3.prj
# BGD_adm0.dbf  BGD_adm1.cpg  BGD_adm1.shp  BGD_adm2.dbf	BGD_adm3.cpg  BGD_adm3.shp
# BGD_adm0.prj  BGD_adm1.csv  BGD_adm1.shx  BGD_adm2.prj	BGD_adm3.csv  BGD_adm3.shx

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
# !pip install geopandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.6/323.6 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.1/24.1 MB 79.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 121.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 73.4 MB/s eta 0:00:00
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
os.listdir()
# Out:
# ['.config', 'drive', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')

# Check files in your drive folder
# !ls "/content/drive/My Drive/BGD_adm"  # Update this path to match your folder
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# BGD_adm0.cpg  BGD_adm0.shp  BGD_adm1.dbf  BGD_adm2.cpg	BGD_adm2.shp  BGD_adm3.dbf  license.txt
# BGD_adm0.csv  BGD_adm0.shx  BGD_adm1.prj  BGD_adm2.csv	BGD_adm2.shx  BGD_adm3.prj
# BGD_adm0.dbf  BGD_adm1.cpg  BGD_adm1.shp  BGD_adm2.dbf	BGD_adm3.cpg  BGD_adm3.shp
# BGD_adm0.prj  BGD_adm1.csv  BGD_adm1.shx  BGD_adm2.prj	BGD_adm3.csv  BGD_adm3.shx

# %%
shapefile_path = "/content/drive/My Drive/BGD_adm/BGD_adm1.shp"
gdf = gpd.read_file(shapefile_path)

# Display the first few rows of the data
print(gdf.head())

# Plot the shapefile
gdf.plot(figsize=(8, 6), color="lightblue", edgecolor="black")
# Out:
#    ID_0  ISO      NAME_0  ID_1      NAME_1  TYPE_1 ENGTYPE_1 NL_NAME_1  \
# 0    20  BGD  Bangladesh     1     Barisal  Bibhag  Division      None
# 1    20  BGD  Bangladesh     2  Chittagong  Bibhag  Division      None
# 2    20  BGD  Bangladesh     3       Dhaka  Bibhag  Division      None
# 3    20  BGD  Bangladesh     4      Khulna  Bibhag  Division      None
# 4    20  BGD  Bangladesh     5    Rajshahi  Bibhag  Division      None
#
#                                    VARNAME_1  \
# 0                                  Bakerganj
# 1  Chattagram|Parbattya Chattagram|Rangamati
# 2                                 Daca|Dacca
# 3                                       None
# 4                                       None
#
#                                             geometry
# 0  MULTIPOLYGON (((90.59583 21.73779, 90.59525 21...
# 1  MULTIPOLYGON (((92.27417 20.92611, 92.27444 20...
# 2  MULTIPOLYGON (((90.53539 23.05746, 90.53539 23...
# ...
