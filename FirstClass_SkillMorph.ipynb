# %% [markdown]
# <a href="https://colab.research.google.com/github/BipulLab/Geospatial-in-R/blob/main/FirstClass_SkillMorph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **First Class Skillmorph**

# %%
print("welcome to this class")
# Out:
# welcome to this class
